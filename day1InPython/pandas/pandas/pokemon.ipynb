# %% [markdown]
# Import Pandas

# %%
import pandas as pd 

df = pd.read_csv('pokemon_data.csv')
# df = pd.read_excel('pokemon_data.xlsx')
# df = pd.read_csv('pokemon_data.csv', delimiter='\t')
# df = pd.read_json()

# %% [markdown]
# Viewing data

# %%
df.head(5)
# df.tail()
# df.info()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# Reading Data

# %%
# Read Headers
df.columns

# Read each Column
df['HP']

# Reading multiple Column
df[['Name','HP','Legendary']]

# Read each Row
df.iloc[3]
df.iloc[1:5]
for index, row in df.iterrows():
    index, row[3:]
print(df.loc[df['Name'] == 'Ivysaur'])

# Read specific character
df.iloc[3,2]
# Out:
#    #     Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 1  2  Ivysaur  Grass  Poison  60      62       63       80       80     60
#
#    Generation  Legendary
# 1           1      False
# 'Grass'

# %% [markdown]
# Mean/Median/Mode/Std
#
# Sorting

# %%
# Describes the whole dataset
df.describe()
# Mean
df.mean(numeric_only=True)
# Median
df.median(numeric_only=True)
# Standard Deviation
df.std(numeric_only=True)

# Sorting 
df.sort_values('HP', ascending=False)

# %% [markdown]
# Adding a column

# %%
# Changing the data
# Manually
# df['Total'] = df['HP'] + df['Attack'] 

df['Total'] = df.iloc[:,4:10].sum(axis=1)

# Rearranging the dataset
cols = list(df.columns)
df = df[cols[:4] + [cols[-1]] + cols[4:12]]

# df = df.drop(columns='Total')
print(df.head(3))
# Out:
#    #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1  Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2    Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3   Venusaur  Grass  Poison    525  80      82       83      100      100
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False

# %% [markdown]
# Saving into  new file

# %%
df.to_csv('new.csv', index=False)
df.to_excel('new.xlsx', index=False)
df.to_csv('new.txt', index=False, sep='\t')
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# Filtering Data

# %%
new_df = df.loc[(df['Type 1'] == 'Fire') & (df['HP'] > 100)]
# new_df.to_csv('new2.csv')

new_df = new_df.reset_index(drop=True)
# or
new_df.reset_index(drop=True, inplace=True)
new_df
# Out:
#      #                     Name Type 1    Type 2  Total   HP  Attack  Defense  \
# 0  244                    Entei   Fire       NaN    580  115     115       85
# 1  250                    Ho-oh   Fire    Flying    680  106     130       90
# 2  500                   Emboar   Fire  Fighting    528  110     123       65
# 3  555  DarmanitanStandard Mode   Fire       NaN    480  105     140       55
# 4  555       DarmanitanZen Mode   Fire   Psychic    540  105      30      105
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       90       75    100           2       True
# 1      110      154     90           2       True
# 2      100       65     65           5      False
# 3       30       55     95           5      False
# 4      140      105     55           5      False

# %% [markdown]
# Regex Filtering

# %%
# Contains
# df.loc[df['Name'].str.contains('Mega')]
# Not comtains
# df.loc[~df['Name'].str.contains('Mega')]

# Regex
import re
print(df.loc[df['Type 1'].str.contains('fire|grass', flags=re.I, regex=True)])
df.loc[(df['Type 1'].str.contains('fire', flags=re.I, regex=True))&df['Type 2'].str.contains('flying', flags=re.I, regex=True)]
# Out:
#        #                   Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass  Poison    318   45      49       49
# 1      2                Ivysaur  Grass  Poison    405   60      62       63
# 2      3               Venusaur  Grass  Poison    525   80      82       83
# 3      3  VenusaurMega Venusaur  Grass  Poison    625   80     100      123
# 4      4             Charmander   Fire     NaN    309   39      52       43
# ..   ...                    ...    ...     ...    ...  ...     ...      ...
# 735  667                 Litleo   Fire  Normal    369   62      50       58
# 736  668                 Pyroar   Fire  Normal    507   86      68       72
# 740  672                 Skiddo  Grass     NaN    350   66      65       48
# 741  673                 Gogoat  Grass     NaN    531  123     100       62
# 799  721              Volcanion   Fire   Water    600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# Conditional Changes

# %%
df.loc[df['Type 1'] == 'Fire', ['Type 1','Type 2']] = ['Flame','Water']
df.loc[df['Type 1']=='Flame']

print(df.loc[df['Type 1'] == 'Flame'])
# Out:
#        #                       Name Type 1 Type 2  Total   HP  Attack  \
# 4      4                 Charmander  Flame  Water    309   39      52
# 5      5                 Charmeleon  Flame  Water    405   58      64
# 6      6                  Charizard  Flame  Water    534   78      84
# 7      6  CharizardMega Charizard X  Flame  Water    634   78     130
# 8      6  CharizardMega Charizard Y  Flame  Water    634   78     104
# 42    37                     Vulpix  Flame  Water    299   38      41
# 43    38                  Ninetales  Flame  Water    505   73      76
# 63    58                  Growlithe  Flame  Water    350   55      70
# 64    59                   Arcanine  Flame  Water    555   90     110
# 83    77                     Ponyta  Flame  Water    410   50      85
# 84    78                   Rapidash  Flame  Water    500   65     100
# 135  126                     Magmar  Flame  Water    495   65      95
# ...
