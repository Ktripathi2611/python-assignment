# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('pizza.csv')
print(df)
# Out:
#        Unnamed: 0        X           id        date      time         name  \
# 0               1      1.0  2015-000001  2015-01-01  11:38:36     hawaiian
# 1               2      2.0  2015-000002  2015-01-01  11:57:40  classic_dlx
# 2               3      3.0  2015-000002  2015-01-01  11:57:40     mexicana
# 3               4      NaN  2015-000002  2015-01-01  11:57:40     thai_ckn
# 4               5      NaN  2015-000002  2015-01-01  11:57:40  five_cheese
# ...           ...      ...          ...         ...       ...          ...
# 49572       49570  49570.0  2015-021348  2015-12-31  21:23:10  four_cheese
# 49573       49571  49571.0  2015-021348  2015-12-31  21:23:10   napolitana
# 49574       49572  49572.0  2015-021348  2015-12-31  21:23:10  ckn_alfredo
# 49575       49573  49573.0  2015-021349  2015-12-31  22:09:54     mexicana
# 49576       49574  49574.0  2015-021350  2015-12-31  23:02:05      bbq_ckn
#
#       size     type  price  remark
# ...

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 49572    False
# 49573    False
# 49574    False
# 49575    False
# 49576    False
# Length: 49577, dtype: bool

# %%
df.isna()
# Out:
#        Unnamed: 0      X     id   date   time   name   size   type  price  \
# 0           False  False  False  False  False  False  False  False  False
# 1           False  False  False  False  False  False  False  False  False
# 2           False  False  False  False  False  False  False  False  False
# 3           False   True  False  False  False  False  False  False  False
# 4           False   True  False  False  False  False  False  False  False
# ...           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 49572       False  False  False  False  False  False  False  False  False
# 49573       False  False  False  False  False  False  False  False  False
# 49574       False  False  False  False  False  False  False  False  False
# 49575       False  False  False  False  False  False  False  False  False
# 49576       False  False  False  False  False  False  False  False  False
#
#        remark
# 0        True
# 1        True
# 2        True
# 3        True
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0        0
# X                 3
# id                0
# date              0
# time              0
# name              0
# size              1
# type              0
# price             0
# remark        49577
# dtype: int64

# %%
df['size'].fillna('M')
# Out:
# 0        M
# 1        M
# 2        M
# 3        L
# 4        L
#         ..
# 49572    L
# 49573    S
# 49574    M
# 49575    L
# 49576    S
# Name: size, Length: 49577, dtype: object

# %%
df['size'].fillna(12, inplace=True)
print(df)
# Out:
#        Unnamed: 0        X           id        date      time         name  \
# 0               1      1.0  2015-000001  2015-01-01  11:38:36     hawaiian
# 1               2      2.0  2015-000002  2015-01-01  11:57:40  classic_dlx
# 2               3      3.0  2015-000002  2015-01-01  11:57:40     mexicana
# 3               4      NaN  2015-000002  2015-01-01  11:57:40     thai_ckn
# 4               5      NaN  2015-000002  2015-01-01  11:57:40  five_cheese
# ...           ...      ...          ...         ...       ...          ...
# 49572       49570  49570.0  2015-021348  2015-12-31  21:23:10  four_cheese
# 49573       49571  49571.0  2015-021348  2015-12-31  21:23:10   napolitana
# 49574       49572  49572.0  2015-021348  2015-12-31  21:23:10  ckn_alfredo
# 49575       49573  49573.0  2015-021349  2015-12-31  22:09:54     mexicana
# 49576       49574  49574.0  2015-021350  2015-12-31  23:02:05      bbq_ckn
#
#       size     type  price  remark
# ...

# %%
df.drop(columns=['remark'],inplace=True)
df
# Out:
#        Unnamed: 0        X           id        date      time         name  \
# 0               1      1.0  2015-000001  2015-01-01  11:38:36     hawaiian
# 1               2      2.0  2015-000002  2015-01-01  11:57:40  classic_dlx
# 2               3      3.0  2015-000002  2015-01-01  11:57:40     mexicana
# 3               4      NaN  2015-000002  2015-01-01  11:57:40     thai_ckn
# 4               5      NaN  2015-000002  2015-01-01  11:57:40  five_cheese
# ...           ...      ...          ...         ...       ...          ...
# 49572       49570  49570.0  2015-021348  2015-12-31  21:23:10  four_cheese
# 49573       49571  49571.0  2015-021348  2015-12-31  21:23:10   napolitana
# 49574       49572  49572.0  2015-021348  2015-12-31  21:23:10  ckn_alfredo
# 49575       49573  49573.0  2015-021349  2015-12-31  22:09:54     mexicana
# 49576       49574  49574.0  2015-021350  2015-12-31  23:02:05      bbq_ckn
#
#       size     type  price
# 0        M  classic  13.25
# ...

# %%
df.isna().sum()
df
# Out:
#        Unnamed: 0        X           id        date      time         name  \
# 0               1      1.0  2015-000001  2015-01-01  11:38:36     hawaiian
# 1               2      2.0  2015-000002  2015-01-01  11:57:40  classic_dlx
# 2               3      3.0  2015-000002  2015-01-01  11:57:40     mexicana
# 3               4      NaN  2015-000002  2015-01-01  11:57:40     thai_ckn
# 4               5      NaN  2015-000002  2015-01-01  11:57:40  five_cheese
# ...           ...      ...          ...         ...       ...          ...
# 49572       49570  49570.0  2015-021348  2015-12-31  21:23:10  four_cheese
# 49573       49571  49571.0  2015-021348  2015-12-31  21:23:10   napolitana
# 49574       49572  49572.0  2015-021348  2015-12-31  21:23:10  ckn_alfredo
# 49575       49573  49573.0  2015-021349  2015-12-31  22:09:54     mexicana
# 49576       49574  49574.0  2015-021350  2015-12-31  23:02:05      bbq_ckn
#
#       size     type  price
# 0        M  classic  13.25
# ...

# %%
df['size'].duplicated().sum()
df
# Out:
#        Unnamed: 0        X           id        date      time         name  \
# 0               1      1.0  2015-000001  2015-01-01  11:38:36     hawaiian
# 1               2      2.0  2015-000002  2015-01-01  11:57:40  classic_dlx
# 2               3      3.0  2015-000002  2015-01-01  11:57:40     mexicana
# 3               4      NaN  2015-000002  2015-01-01  11:57:40     thai_ckn
# 4               5      NaN  2015-000002  2015-01-01  11:57:40  five_cheese
# ...           ...      ...          ...         ...       ...          ...
# 49572       49570  49570.0  2015-021348  2015-12-31  21:23:10  four_cheese
# 49573       49571  49571.0  2015-021348  2015-12-31  21:23:10   napolitana
# 49574       49572  49572.0  2015-021348  2015-12-31  21:23:10  ckn_alfredo
# 49575       49573  49573.0  2015-021349  2015-12-31  22:09:54     mexicana
# 49576       49574  49574.0  2015-021350  2015-12-31  23:02:05      bbq_ckn
#
#       size     type  price
# 0        M  classic  13.25
# ...

# %%
df.dropna()
# Out:
#        Unnamed: 0        X           id        date      time         name  \
# 0               1      1.0  2015-000001  2015-01-01  11:38:36     hawaiian
# 1               2      2.0  2015-000002  2015-01-01  11:57:40  classic_dlx
# 2               3      3.0  2015-000002  2015-01-01  11:57:40     mexicana
# 5               6      6.0  2015-000002  2015-01-01  11:57:40    ital_supr
# 6               7      7.0  2015-000003  2015-01-01  12:12:28   prsc_argla
# ...           ...      ...          ...         ...       ...          ...
# 49572       49570  49570.0  2015-021348  2015-12-31  21:23:10  four_cheese
# 49573       49571  49571.0  2015-021348  2015-12-31  21:23:10   napolitana
# 49574       49572  49572.0  2015-021348  2015-12-31  21:23:10  ckn_alfredo
# 49575       49573  49573.0  2015-021349  2015-12-31  22:09:54     mexicana
# 49576       49574  49574.0  2015-021350  2015-12-31  23:02:05      bbq_ckn
#
#       size     type  price
# 0        M  classic  13.25
# ...

# %%
#to show rows and commlum

df.shape
# Out:
# (49577, 9)

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#        Unnamed: 0        X           id        date      time         name  \
# 0               1      1.0  2015-000001  2015-01-01  11:38:36     hawaiian
# 1               2      2.0  2015-000002  2015-01-01  11:57:40  classic_dlx
# 2               3      3.0  2015-000002  2015-01-01  11:57:40     mexicana
# 3               4      NaN  2015-000002  2015-01-01  11:57:40     thai_ckn
# 4               5      NaN  2015-000002  2015-01-01  11:57:40  five_cheese
# ...           ...      ...          ...         ...       ...          ...
# 49572       49570  49570.0  2015-021348  2015-12-31  21:23:10  four_cheese
# 49573       49571  49571.0  2015-021348  2015-12-31  21:23:10   napolitana
# 49574       49572  49572.0  2015-021348  2015-12-31  21:23:10  ckn_alfredo
# 49575       49573  49573.0  2015-021349  2015-12-31  22:09:54     mexicana
# 49576       49574  49574.0  2015-021350  2015-12-31  23:02:05      bbq_ckn
#
#       size     type  price
# 0        M  classic  13.25
# ...

# %%
df.shape
# Out:
# (49574, 9)

# %%
df.sort_values('price')
df
# Out:
#        Unnamed: 0        X           id        date      time         name  \
# 0               1      1.0  2015-000001  2015-01-01  11:38:36     hawaiian
# 1               2      2.0  2015-000002  2015-01-01  11:57:40  classic_dlx
# 2               3      3.0  2015-000002  2015-01-01  11:57:40     mexicana
# 3               4      NaN  2015-000002  2015-01-01  11:57:40     thai_ckn
# 4               5      NaN  2015-000002  2015-01-01  11:57:40  five_cheese
# ...           ...      ...          ...         ...       ...          ...
# 49572       49570  49570.0  2015-021348  2015-12-31  21:23:10  four_cheese
# 49573       49571  49571.0  2015-021348  2015-12-31  21:23:10   napolitana
# 49574       49572  49572.0  2015-021348  2015-12-31  21:23:10  ckn_alfredo
# 49575       49573  49573.0  2015-021349  2015-12-31  22:09:54     mexicana
# 49576       49574  49574.0  2015-021350  2015-12-31  23:02:05      bbq_ckn
#
#       size     type  price
# 0        M  classic  13.25
# ...

# %%
df.sort_values('price',ascending=0)
# Out:
#        Unnamed: 0        X           id        date      time       name size  \
# 40510       40508  40508.0  2015-017492  2015-10-24  18:58:20  the_greek  XXL
# 10479       10477  10477.0  2015-004498  2015-03-17  16:22:45  the_greek  XXL
# 23351       23349  23349.0  2015-010075  2015-06-18  16:03:06  the_greek  XXL
# 6479         6477   6477.0  2015-002813  2015-02-16  18:15:02  the_greek  XXL
# 38689       38687  38687.0  2015-016753  2015-10-10  17:54:55  the_greek  XXL
# ...           ...      ...          ...         ...       ...        ...  ...
# 20531       20529  20529.0  2015-008857  2015-05-29  13:21:21  pepperoni    S
# 2404         2402   2402.0  2015-001047  2015-01-18  14:50:37  pepperoni    S
# 42065       42063  42063.0  2015-018167  2015-11-06  13:35:40  pepperoni    S
# 2398         2396   2396.0  2015-001043  2015-01-18  14:07:36  pepperoni    S
# 11682       11680  11680.0  2015-005041  2015-03-26  17:43:00  pepperoni    S
#
#           type  price
# ...

# %%
df.sort_values('price',ascending=1)
# Out:
#        Unnamed: 0        X           id        date      time       name size  \
# 23649       23647  23647.0  2015-010200  2015-06-20  17:28:19  pepperoni    S
# 24976       24974  24974.0  2015-010765  2015-06-30  14:27:39  pepperoni    S
# 37248       37246  37246.0  2015-016127  2015-09-29  13:19:39  pepperoni    S
# 11009       11007  11007.0  2015-004732  2015-03-21  13:02:15  pepperoni    S
# 24999       24997  24997.0  2015-010776  2015-06-30  16:40:51  pepperoni    S
# ...           ...      ...          ...         ...       ...        ...  ...
# 19814       19812  19812.0  2015-008546  2015-05-23  18:48:51  the_greek  XXL
# 48414       48412  48412.0  2015-020866  2015-12-20  19:16:20  the_greek  XXL
# 30803       30801  30801.0  2015-013341  2015-08-11  11:51:24  the_greek  XXL
# 43886       43884  43884.0  2015-018919  2015-11-19  16:58:26  the_greek  XXL
# 11081       11079  11079.0  2015-004761  2015-03-21  18:10:58  the_greek  XXL
#
#           type  price
# ...

# %%
df.sort_values(['price','time'],ascending=[1,1])
# Out:
#        Unnamed: 0        X           id        date      time       name size  \
# 19312       19310  19310.0  2015-008322  2015-05-20  11:19:06  pepperoni    S
# 21381       21379  21379.0  2015-009205  2015-06-04  11:21:04  pepperoni    S
# 24365       24363  24363.0  2015-010510  2015-06-26  11:25:23  pepperoni    S
# 9710         9708   9708.0  2015-004177  2015-03-12  11:26:04  pepperoni    S
# 20940       20938  20938.0  2015-009026  2015-06-01  11:29:05  pepperoni    S
# ...           ...      ...          ...         ...       ...        ...  ...
# 48414       48412  48412.0  2015-020866  2015-12-20  19:16:20  the_greek  XXL
# 36653       36651  36651.0  2015-015874  2015-09-22  20:26:26  the_greek  XXL
# 41986       41984  41984.0  2015-018139  2015-11-05  20:28:52  the_greek  XXL
# 14288       14286  14286.0  2015-006150  2015-04-13  21:15:17  the_greek  XXL
# 32831       32829  32829.0  2015-014227  2015-08-25  22:17:58  the_greek  XXL
#
#           type  price
# ...

# %%
df.sort_values(['price','time'],ascending=[0,0])
# Out:
#        Unnamed: 0        X           id        date      time       name size  \
# 32831       32829  32829.0  2015-014227  2015-08-25  22:17:58  the_greek  XXL
# 14288       14286  14286.0  2015-006150  2015-04-13  21:15:17  the_greek  XXL
# 41986       41984  41984.0  2015-018139  2015-11-05  20:28:52  the_greek  XXL
# 36653       36651  36651.0  2015-015874  2015-09-22  20:26:26  the_greek  XXL
# 48414       48412  48412.0  2015-020866  2015-12-20  19:16:20  the_greek  XXL
# ...           ...      ...          ...         ...       ...        ...  ...
# 20940       20938  20938.0  2015-009026  2015-06-01  11:29:05  pepperoni    S
# 9710         9708   9708.0  2015-004177  2015-03-12  11:26:04  pepperoni    S
# 24365       24363  24363.0  2015-010510  2015-06-26  11:25:23  pepperoni    S
# 21381       21379  21379.0  2015-009205  2015-06-04  11:21:04  pepperoni    S
# 19312       19310  19310.0  2015-008322  2015-05-20  11:19:06  pepperoni    S
#
#           type  price
# ...

# %%
df.groupby(['type','size']).count()
# Out:
#               Unnamed: 0     X    id  date  time  name  price
# type    size
# chicken L           4932  4931  4932  4932  4932  4932   4932
#         M           3894  3894  3894  3894  3894  3894   3894
#         S           2224  2224  2224  2224  2224  2224   2224
# classic L           4057  4057  4057  4057  4057  4057   4057
#         M           4112  4112  4112  4112  4112  4112   4112
#         S           6139  6139  6139  6139  6139  6139   6139
#         XL           552   552   552   552   552   552    552
#         XXL           28    28    28    28    28    28     28
# supreme 12             1     1     1     1     1     1      1
#         L           4563  4563  4563  4563  4563  4563   4563
#         M           4046  4045  4046  4046  4046  4046   4046
#         S           3377  3377  3377  3377  3377  3377   3377
# veggie  L           5403  5402  5403  5403  5403  5403   5403
#         M           3583  3583  3583  3583  3583  3583   3583
# ...

# %%
df.groupby(['type','size']).size()
# Out:
# type     size
# chicken  L       4932
#          M       3894
#          S       2224
# classic  L       4057
#          M       4112
#          S       6139
#          XL       552
#          XXL       28
# supreme  12         1
#          L       4563
#          M       4046
#          S       3377
# veggie   L       5403
#          M       3583
#          S       2663
# dtype: int64

# %%
df.groupby(['type','size','name']).size()
# Out:
# type     size  name
# chicken  L     bbq_ckn          992
#                cali_ckn         927
#                ckn_alfredo      188
#                ckn_pesto        399
#                southw_ckn      1016
#                                ...
# veggie   S     mediterraneo     289
#                mexicana         162
#                spin_pesto       404
#                spinach_fet      439
#                veggie_veg       464
# Length: 92, dtype: int64

# %%
df.groupby(['type','size','name']).mean('price')
# Out:
#                              Unnamed: 0             X  price
# type    size name
# chicken L    bbq_ckn       24233.132056  24233.132056  20.75
#              cali_ckn      25096.711974  25096.711974  20.75
#              ckn_alfredo   24689.372340  24689.372340  20.75
#              ckn_pesto     24210.984962  24210.984962  20.75
#              southw_ckn    24892.592520  24892.592520  20.75
# ...                                 ...           ...    ...
# veggie  S    mediterraneo  25559.692042  25559.692042  12.00
#              mexicana      26179.339506  26179.339506  12.00
#              spin_pesto    25532.673267  25532.673267  12.50
#              spinach_fet   22945.280182  22945.280182  12.00
#              veggie_veg    24353.431034  24353.431034  12.00
#
# [92 rows x 3 columns]

# %%
df.groupby(['type','size']).mean('price')
# Out:
#                 Unnamed: 0             X      price
# type    size
# chicken L     24909.257097  24914.307848  20.750000
#         M     24819.166153  24819.166153  16.750000
#         S     24888.069245  24888.069245  12.750000
# classic L     24906.234656  24906.234656  18.367883
#         M     24988.187743  24988.187743  14.732916
#         S     24901.779443  24901.779443  11.381373
#         XL    24183.141304  24183.141304  25.500000
#         XXL   23322.571429  23322.571429  35.950000
# supreme 12        7.000000      7.000000  20.750000
#         L     24709.010519  24709.010519  20.652586
#         M     24726.640880  24732.751298  16.429807
#         S     24886.755108  24886.755108  14.054930
# veggie  L     24465.818064  24470.346168  19.286082
#         M     24809.223835  24809.223835  15.936645
#         S     24551.990612  24551.990612  12.161754

# %% [markdown]
#  matplotlib

# %%
import matplotlib.pyplot as plt

# %%
df
# Out:
#        Unnamed: 0        X           id        date      time         name  \
# 0               1      1.0  2015-000001  2015-01-01  11:38:36     hawaiian
# 1               2      2.0  2015-000002  2015-01-01  11:57:40  classic_dlx
# 2               3      3.0  2015-000002  2015-01-01  11:57:40     mexicana
# 3               4      NaN  2015-000002  2015-01-01  11:57:40     thai_ckn
# 4               5      NaN  2015-000002  2015-01-01  11:57:40  five_cheese
# ...           ...      ...          ...         ...       ...          ...
# 49572       49570  49570.0  2015-021348  2015-12-31  21:23:10  four_cheese
# 49573       49571  49571.0  2015-021348  2015-12-31  21:23:10   napolitana
# 49574       49572  49572.0  2015-021348  2015-12-31  21:23:10  ckn_alfredo
# 49575       49573  49573.0  2015-021349  2015-12-31  22:09:54     mexicana
# 49576       49574  49574.0  2015-021350  2015-12-31  23:02:05      bbq_ckn
#
#       size     type  price
# 0        M  classic  13.25
# ...

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.plot(color=['red','green'])
# Out:
# <Axes: >

# %%
df['name'].value_counts()
# Out:
# name
# classic_dlx     2453
# bbq_ckn         2432
# hawaiian        2422
# pepperoni       2418
# thai_ckn        2371
# cali_ckn        2370
# sicilian        1938
# spicy_ital      1924
# southw_ckn      1917
# big_meat        1914
# four_cheese     1902
# ital_supr       1884
# veggie_veg      1526
# mexicana        1484
# napolitana      1464
# prsc_argla      1457
# spinach_fet     1446
# peppr_salami    1446
# ital_cpcllo     1438
# the_greek       1420
# five_cheese     1409
# pep_msh_pep     1359
# green_garden     997
# ckn_alfredo      987
# ital_veggie      981
# ckn_pesto        973
# spin_pesto       970
# soppressata      961
# spinach_supr     950
# calabrese        937
# mediterraneo     934
# brie_carre       490
# Name: count, dtype: int64

# %%
df['name'].value_counts().values
# Out:
# array([2453, 2432, 2422, 2418, 2371, 2370, 1938, 1924, 1917, 1914, 1902,
#        1884, 1526, 1484, 1464, 1457, 1446, 1446, 1438, 1420, 1409, 1359,
#         997,  987,  981,  973,  970,  961,  950,  937,  934,  490],
#       dtype=int64)

# %%
plt.bar(df['name'].value_counts().index, df['name'].value_counts().values)
plt.xlabel('Pizza type')
plt.ylabel('Count of pizza')
plt.show()

# %%
plt.figure(figsize=[40,20])
name_counts = df['name'].value_counts()
plt.bar(name_counts.index, name_counts.values)
plt.xlabel('Name')
plt.ylabel('Count')
plt.title('Name Frequencies')
plt.show()

# %%
plt.figure(figsize=[20,10])
plt.barh(df['name'].value_counts().index, df['name'].value_counts().values)
plt.xlabel('Pizza type')
plt.ylabel('Count of pizza')
plt.show()

# %%
plt.figure(figsize=(8, 8))
plt.pie(df['name'].value_counts(), labels=df['name'].value_counts().index, autopct='%1.1f%%', startangle=90)
plt.title('Pizza Types Distribution')
plt.axis('equal')  
plt.show()
